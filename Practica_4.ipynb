# %% [markdown]
# <a href="https://colab.research.google.com/github/a24308052690149-design/astro-platform-starter/blob/main/Practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AXEL VALENTIN SANCHEZ SAUCEDO 4ºF
# # Practica 4 Manejo de listas de python

# %% [markdown]
# LAS Listas se utilizan para almacenar varios elementos en una sola variable las listas son un de los cuartos elementos ultilizados en python para hacer coneciones de datos ,los otros tres son tupla,set  y diccionario,todos con difedrentes cuadidades y usos.Las listas se creean utilizado cochetes.

# %%
print("ejemplo.crea una lista")
frutas = ["manzana","platano","sandia","melon"]
print (frutas)
# Out:
# ejemplo.crea una lista
# ['manzana', 'platano', 'sandia', 'melon']

# %% [markdown]
# Lista de elementos. Los elementos de la lista estan ordenados , se pueden cambiar y permite valores dupicados. Los elementos de la lista estan indexados,el primer elemento tiene indice (0),el segundoelemento (1) ect, ordenado.cuando decimos que las listas estan ordenadas,significa que los elementos tiene un orden  definidos y ese orden  no cambia si agrega numeros elementos a una lista los numeros elementos se colocaran al final de la lista

# %% [markdown]
# Las listas se pueden cambiar ,lo que significa que podemos cambiar,agregar y eliminae elementos de una lista despues de hablera creado permitir dupilcado dado que las listas estan indexadas ,las listas pueden tener elementos con el mismo valor

# %%
print ("ejemplo , Las listas pueden permitir valores dupicados")
frutas = ["manzana", "platano", "pera","manzana", "fresa", "pera"]
print(frutas)
# Out:
# ejemplo , Las listas pueden permitir valores dupicados
# ['manzana', 'platano', 'pera', 'manzana', 'fresa', 'pera']

# %% [markdown]
# Elementos de las listas tipos de datos , Los elementos de las listas pueden ser de cualquier tipo de dato.

# %%
print("ejemlo tipo de datos  de cadena,int, y boleanos")
frutas = ["manzana", "platano", "fresa"]
numeros =(1,2,3,4,5)
Boleanos = (True,False,False)
print(frutas)
print(numeros)
print(Boleanos)
# Out:
# ejemlo tipo de datos  de cadena,int, y boleanos
# ['manzana', 'platano', 'fresa']
# (1, 2, 3, 4, 5)
# (True, False, False)

# %% [markdown]
# Una lista puede contene diferentes tipos de datos , ejemplos una lista con escalera ,numeros y valores boleanos

# %%
lista = ["abcd", 34, False, "nose", 50 , True]
print (lista)
# Out:
# ['abcd', 34, False, 'nose', 50, True]

# %% [markdown]
# python elementos de la lista de aceso aceder a elementos . los elementos de las lista  estan indexado referencia al nuemero de indice ejemplo imprime el segundo elemento de  la lista.

# %%
furtas = ["manzana", "kiwi", "cereza"]
print(furtas[1])
# Out:
# kiwi

# %% [markdown]
# La indexacion negativa. significa comenzar desde el final . -1 se refiere al ultimo,-2 se refire al penumitimo elemento,ect.
# ejemplo impri,e el ultimo de la siguiente lista

# %%
alumnos = ["jose","maria", "keila", "violeta"]
print (alumnos [-1])
# Out:
# violeta

# %% [markdown]
# rango ded indices,puede especificar una varidad de indices especificando donde comenzar ydonde finalizar el rango, el valor de retono seria  una nueva lista con los elementos especificos ejemplos devuelven eltercer ,cuato y quinti

# %%
frutas = ["Manzana","banana","platano","fresa","naraja","cereza"," melon","mango"]
print(frutas [2:4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2696929566.py in <cell line: 0>()
#       1 frutas = ["Manzana","banana","platano","fresa","naraja","cereza"," melon","mango"]
# ----> 2 print(frutas [2:4])
#
# TypeError: 'list' object is not callable
